# %% [markdown]
# <a href="https://colab.research.google.com/github/githuno/LEARN-quantum/blob/main/20240117_qplat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 量子GUIシミュレータ (QPlat)
#
# [IBM Quantum](https://quantum-computing.ibm.com/) の Composer 相当の「ノーコードで量子回路のシミュレーションができるツール」です。
#
# マニュアル: https://qiita.com/KeiichiroHiga/items/95450143c8ed9a580f31
#
# ## 準備
#
# まず、http://qplat-education.devel-q.com/ をブラウザで開きます。
#
# デフォルトで幾つかのサンプルが入っているのでクリアします。図のように赤丸のところのゴミ箱をクリックしてください。
#
# ![qplat01.png](data:image/png;base64,...)
#
# これで綺麗な状態になりました。
#
# ![qplat02.png](data:image/png;base64,...)

# %% [markdown]
# ## サンプルを実行してみよう
#
# ![qplat03.png](data:image/png;base64,...)
#
# 譜面のような 3 本線は上から順に、量子ビット 0、量子ビット 1、量子ビット 2 に対応します。譜面のような 3 本線は上から順に、量子ビット 0、量子ビット 1、量子ビット 2 に対応します。古典的な論理回路の線に相当するものです (要するに論理回路レベルの底レイヤで計算するということです・・・)。
#
# ここで唐突ですが、論理回路の AND ゲートを見てみます。
#
# ![and.png](data:image/png;base64,...)
#
# この AND 回路は量子回路では以下に相当します。
#
# ![qplat07.png](data:image/png;base64,...)
#
# 今回はこの「量子ゲート」の詳細には触れませんが、何かしら古典の論理ゲートに相当する量子版のゲートが存在するようだ・・・ということを感じていただけましたでしょうか？
#
# 次にサンプルの回路を実装しましょう。
#
# ![qplat04.png](data:image/png;base64,...)
#
# 観測を実行します。
#
# ![qplat05.png](data:image/png;base64,...)
#
# `100` が 1000 回という結果が得られました。これは量子ビット 0 が $| 1 \rangle$、量子ビット 1 が $| 0 \rangle$、量子ビット 2 が $| 0 \rangle$ であるような状態が 1000 回得られたことを示しています。なお注意として、Qiskit を使う場合、LBS (Least Significant Bit) が右にくる慣習ですので、`001` という状態として表示されます。
#
# 今回は触れませんが、もっと複雑な回路を実装すると、複数個の観測結果が得られることもあります。この例では 4 つの状態が観測されています。これを踏まえますと、(繰り返しになりますが) サンプルではただ 1 つの状態 `100` だけが観測されていることになります。
#
# ![qplat06.png](data:image/png;base64,...)

# %% [markdown]
# ## 問題を解いてみよう
#
# 1. 量子ゲートを3つ置いて回路を作成して表示してみよう。
# 2. 1で作成した量子回路を観測して結果を表示してみよう。
#
# に取り組んでみましょう。
#
# ### 1. 量子ゲートを3つ置いて回路を作成して表示してみよう。
#
# 適当なゲートを選んで表示してみます。試してみてください。
#
# ![qplat08.png](data:image/png;base64,...)

# %% [markdown]
# ### 2. 1で作成した量子回路を観測して結果を表示してみよう。
#
# 先程の量子回路に、観測用の「M」を配置します。そして「EXECUTE」をクリックしてください。どうでしょう？`100` や `010` など、出したい状態は出せましたか？今回は慣れるための練習問題なので、どういう結果が観測されていても問題ありません。
#
# ![qplat09.png](data:image/png;base64,...)
